# %%
import numpy as np 
import pandas as pd

train_df = pd.read_csv('train.csv')
test_df = pd.read_csv('test.csv')
train_df
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
train_df.isna().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, precision_score, recall_score, confusion_matrix


y = train_df['price_range']
x = train_df.drop(['price_range'], axis=1)
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.15, random_state=42)

plt.figure(figsize=(10,5))
sns.countplot(y=y)
# Out:
# <AxesSubplot:xlabel='count', ylabel='price_range'>

# %% [markdown]
# # Q2

# %%
from sklearn.svm import SVC

# %%
svm1 = SVC()
svm1.fit(x_train , y_train)
acc = svm1.score(x_val, y_val)
print ("accuracys= " + str(acc*100) + "%")
# Out:
# accuracys= 97.0%

# %% [markdown]
# # Q3

# %%
svm1 = SVC(kernel="linear")
svm1.fit(x_train , y_train)
acc = svm1.score(x_val, y_val)
print ("accuracys= " + str(acc*100) + "%")
# Out:
# accuracys= 96.66666666666667%

# %%
svm1 = SVC(kernel="rbf")
svm1.fit(x_train , y_train)
acc = svm1.score(x_val, y_val)
print ("accuracys= " + str(acc*100) + "%")
# Out:
# accuracys= 97.0%

# %%
svm1 = SVC(kernel="sigmoid")
svm1.fit(x_train , y_train)
acc = svm1.score(x_val, y_val)
print ("accuracys= " + str(acc*100) + "%")
# Out:
# accuracys= 17.333333333333336%

# %%
svm1 = SVC(kernel="sigmoid", coef0=0.2)
svm1.fit(x_train , y_train)
acc = svm1.score(x_val, y_val)
print ("accuracys= " + str(acc*100) + "%")
# Out:
# accuracys= 14.333333333333334%

# %%
svm1 = SVC(kernel="poly", degree=2)
svm1.fit(x_train , y_train)
acc = svm1.score(x_val, y_val)
print ("accuracys= " + str(acc*100) + "%")
# Out:
# accuracys= 96.66666666666667%

# %%
svm1 = SVC(kernel="poly", degree=3)
svm1.fit(x_train , y_train)
acc = svm1.score(x_val, y_val)
print ("accuracys= " + str(acc*100) + "%")
# Out:
# accuracys= 96.33333333333334%

# %%
svm1 = SVC(kernel="poly", degree=4)
svm1.fit(x_train , y_train)
acc = svm1.score(x_val, y_val)
print ("accuracys= " + str(acc*100) + "%")
# Out:
# accuracys= 96.0%

# %%
svm1 = SVC(kernel="poly", degree=10)
svm1.fit(x_train , y_train)
acc = svm1.score(x_val, y_val)
print ("accuracys= " + str(acc*100) + "%")
# Out:
# accuracys= 94.66666666666667%

# %%
svm1 = SVC(kernel="poly", degree=100)
svm1.fit(x_train , y_train)
acc = svm1.score(x_val, y_val)
print ("accuracys= " + str(acc*100) + "%")
# Out:
# accuracys= 69.66666666666667%

# %% [markdown]
# # Q5,6

# %%
X = train_df.drop(['price_range'], axis=1)
y = train_df['price_range']

min_value = X['battery_power'].min()
max_value = X['battery_power'].max()

bins = np.linspace(min_value,max_value,4)
bins
# Out:
# array([ 501., 1000., 1499., 1998.])

# %%
labels = ['low', 'medium', 'high']

X['battery_power'] = pd.cut(X['battery_power'], bins=bins, labels=labels, include_lowest=True)
X
# Out:
#      battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0              low     0          2.2         0   1       0           7
# 1           medium     1          0.5         1   0       1          53
# 2              low     1          0.5         1   2       1          41
# 3              low     1          2.5         0   0       0          10
# 4             high     1          1.2         0  13       1          44
# ...            ...   ...          ...       ...  ..     ...         ...
# 1995           low     1          0.5         1   0       1           2
# 1996          high     1          2.6         1   0       0          39
# 1997          high     0          0.9         1   1       1          36
# 1998          high     0          0.9         0   4       1          46
# 1999           low     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
plt.hist(X['battery_power'], bins=3)
# Out:
# (array([697., 641., 662.]),
#  array([0.        , 0.66666667, 1.33333333, 2.        ]),
#  <BarContainer object of 3 artists>)

# %%
bins = [0, 499, 1499, 2000]
X = train_df.drop(['price_range'], axis=1)
y = train_df['price_range']

min_value = X['battery_power'].min()
max_value = X['battery_power'].max()

labels = ['low', 'medium', 'high']

X['battery_power'] = pd.cut(X['battery_power'], bins=bins, labels=labels, include_lowest=True)
plt.hist(X['battery_power'], bins=3)
# Out:
# (array([1338.,    0.,  662.]),
#  array([0.        , 0.33333333, 0.66666667, 1.        ]),
#  <BarContainer object of 3 artists>)

# %%
bins = [0, 750, 1750, 2000]
X = train_df.drop(['price_range'], axis=1)
y = train_df['price_range']

min_value = X['battery_power'].min()
max_value = X['battery_power'].max()

labels = ['low', 'medium', 'high']

X['battery_power'] = pd.cut(X['battery_power'], bins=bins, labels=labels, include_lowest=True)
plt.hist(X['battery_power'], bins=3)
# Out:
# (array([1312.,  359.,  329.]),
#  array([0.        , 0.66666667, 1.33333333, 2.        ]),
#  <BarContainer object of 3 artists>)

# %%
X = train_df.drop(['price_range'], axis=1)
y = train_df['price_range']

min_value = X['battery_power'].min()
max_value = X['battery_power'].max()

bins = np.linspace(min_value,max_value,4)

labels = ['low', 'medium', 'high']

X['battery_power'] = pd.cut(X['battery_power'], bins=bins, labels=labels, include_lowest=True)

d = pd.get_dummies(X['battery_power'], prefix='battery_power')
X = X.join(d)
X.drop(['battery_power'], inplace=True, axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

svm1 = SVC()
svm1.fit(X_train, y_train)
acc = svm1.score(X_test, y_test)
print ("acc= " + str(acc*100) + "%")
# Out:
# acc= 83.0%

# %%
train_df.info()
#no categorical data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
x_train.min()
# Out:
# battery_power    501.0
# blue               0.0
# clock_speed        0.5
# dual_sim           0.0
# fc                 0.0
# four_g             0.0
# int_memory         2.0
# m_dep              0.1
# mobile_wt         80.0
# n_cores            1.0
# pc                 0.0
# px_height          0.0
# px_width         500.0
# ram              256.0
# sc_h               5.0
# sc_w               0.0
# talk_time          2.0
# three_g            0.0
# touch_screen       0.0
# wifi               0.0
# dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

x = train_df.drop("price_range", axis=1, inplace=False)
x.min()
# Out:
# battery_power    501.0
# blue               0.0
# clock_speed        0.5
# dual_sim           0.0
# fc                 0.0
# four_g             0.0
# int_memory         2.0
# m_dep              0.1
# mobile_wt         80.0
# n_cores            1.0
# pc                 0.0
# px_height          0.0
# px_width         500.0
# ram              256.0
# sc_h               5.0
# sc_w               0.0
# talk_time          2.0
# three_g            0.0
# touch_screen       0.0
# wifi               0.0
# dtype: float64

# %%
sc = StandardScaler()
x = sc.fit_transform(x)

# %%
log_train_x, log_test_x , log_train_y , log_test_y = train_test_split(x , y , test_size = 0.2, random_state = 42)
print(log_train_x.shape)
print(log_test_x.shape)
# Out:
# (1600, 20)
# (400, 20)

# %%
svm1 = SVC()
svm1.fit(log_train_x , log_train_y)
acc = svm1.score(log_test_x, log_test_y)
print ("acc= " + str(acc*100) + "%")
# Out:
# acc= 89.25%

# %%
X = train_df.drop(['price_range'], axis=1)
y = train_df['price_range']

X['area'] = X['px_width'] * X['px_height']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
svm1 = SVC()
svm1.fit(X_train, y_train)
acc = svm1.score(X_test, y_test)
print ("acc= " + str(acc*100) + "%")
# Out:
# acc= 31.0%

# %% [markdown]
# # Q8,9

# %%
y = train_df['price_range']
x = train_df.drop(['price_range'], axis=1)
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.15, random_state=42)

from sklearn.tree import DecisionTreeClassifier
DT = DecisionTreeClassifier(random_state=0)
DT = DT.fit(x_train, y_train)
acc = DT.score(x_val, y_val)
print ("acc= " + str(acc*100) + "%")
# Out:
# acc= 84.66666666666667%

# %%
from sklearn import tree
plt.figure(figsize=(30,30))
tree.plot_tree(DT, filled=True, fontsize=5)
plt.show()

# %%
X = train_df.drop(['price_range'], axis=1)
y = train_df['price_range']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

DT = tree.DecisionTreeClassifier(max_depth=5)
DT = DT.fit(X_train, y_train)
acc = DT.score(x_val, y_val)
print ("acc= " + str(acc*100) + "%")
# Out:
# acc= 89.33333333333333%

# %%
X = train_df.drop(['price_range'], axis=1)
y = train_df['price_range']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

DT = tree.DecisionTreeClassifier(max_depth=10)
DT = DT.fit(X_train, y_train)
acc = DT.score(x_val, y_val)
print ("acc= " + str(acc*100) + "%")
# Out:
# acc= 98.33333333333333%

# %%
X = train_df.drop(['price_range'], axis=1)
y = train_df['price_range']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

DT = tree.DecisionTreeClassifier(max_depth=50)
DT = DT.fit(X_train, y_train)
acc = DT.score(x_val, y_val)
print ("acc= " + str(acc*100) + "%")
# Out:
# acc= 98.66666666666667%

# %%
X = train_df.drop(['price_range'], axis=1)
y = train_df['price_range']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

DT = tree.DecisionTreeClassifier(max_features=10)
DT = DT.fit(X_train, y_train)
acc = DT.score(x_val, y_val)
print ("acc= " + str(acc*100) + "%")
# Out:
# acc= 98.33333333333333%

# %%
X = train_df.drop(['price_range'], axis=1)
y = train_df['price_range']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

DT = tree.DecisionTreeClassifier(max_features=5)
DT = DT.fit(X_train, y_train)
acc = DT.score(x_val, y_val)
print ("acc= " + str(acc*100) + "%")
# Out:
# acc= 95.66666666666667%

# %%
X = train_df.drop(['price_range'], axis=1)
y = train_df['price_range']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

DT = tree.DecisionTreeClassifier(max_features=2)
DT = DT.fit(X_train, y_train)
acc = DT.score(x_val, y_val)
print ("acc= " + str(acc*100) + "%")
# Out:
# acc= 91.66666666666666%

# %% [markdown]
# # Q12

# %%
from sklearn.ensemble import RandomForestClassifier
RF = RandomForestClassifier(random_state=0)
RF = RF.fit(X_train, y_train)
acc = RF.score(x_val, y_val)
print ("acc= : " + str(acc*100) + "%")
# Out:
# acc= : 98.0%
